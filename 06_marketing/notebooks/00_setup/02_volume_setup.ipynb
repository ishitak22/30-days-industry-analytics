# %%
CATALOG_NAME = "workspace"
SCHEMA_NAME = "marketing_campaign"
VOLUME_NAME = "raw_files"

volume_full_name = f"{CATALOG_NAME}.{SCHEMA_NAME}.{VOLUME_NAME}"
volume_path = f"/Volumes/{CATALOG_NAME}/{SCHEMA_NAME}/{VOLUME_NAME}/"

print(f"Volume name: {volume_full_name}")
print(f"Volume path: {volume_path}")

# %%
spark.sql(f"""
CREATE VOLUME IF NOT EXISTS {CATALOG_NAME}.{SCHEMA_NAME}.{VOLUME_NAME}
COMMENT 'Raw file landing area for the 06_marketing campaign response project'
""")

# %%
spark.sql(f"SHOW VOLUMES IN {CATALOG_NAME}.{SCHEMA_NAME}").display()

# %%
dbutils.fs.ls(volume_path)
