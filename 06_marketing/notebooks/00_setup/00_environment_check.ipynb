# %%
print("Marketing project environment check")

# %%
spark.version

# %%
# %sql
SELECT current_date() AS run_date, current_user() AS databricks_user

# %%
import mlflow

print("MLflow is available")
print("MLflow tracking URI:", mlflow.get_tracking_uri())
