# %%
raw_file_path = "/Volumes/workspace/marketing_campaign/raw_files/marketing_campaign.csv"

print(raw_file_path)

# %%
dbutils.fs.ls("/Volumes/workspace/marketing_campaign/raw_files/")

# %%
raw_df = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv(raw_file_path)
)

display(raw_df.limit(10))

# %%
print(f"Rows: {raw_df.count()}")
print(f"Columns: {len(raw_df.columns)}")
print(raw_df.columns)
